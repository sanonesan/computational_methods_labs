# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from array import *
import random

h = 0.001
start_time = 0
end_time = 20
epsilon = 0.001
beta2 = 8


x0 = np.array([[1],[1.5]],dtype = float)
x01 = np.array([[1],[2]],dtype = float)
x02 = np.array([[1],[3]],dtype = float)
x03 = np.array([[1],[4]],dtype = float)
x04 = np.array([[2],[5]],dtype = float)
x05 = np.array([[1],[6]],dtype = float)
x06 = np.array([[1],[7]],dtype = float)
x07 = np.array([[1],[8]],dtype = float)
x08 = np.array([[5],[9]],dtype = float)





def react_system(time, x):  
    xx = x[0][0]
    yy = x[1][0]
    yy2_3 = np.power(yy,2/3)
    
    return np.array([[-1 + yy2_3 * (1-xx/3)*(1+xx)*xx ], [((-beta2)*xx*yy2_3/(1+xx) ) + yy ] ])


#Рунге - Кутта
def kaef(k_time, k_h, k_x_i, k_fun):
    k1 = k_h * k_fun(k_time, k_x_i)
    k2 = k_h * k_fun(k_time + k_h/3, k_x_i + k1/3)
    k3 = k_h * k_fun(k_time + k_h/3, k_x_i + (k1+k2)/6)

    k_x_i = k_x_i + (1/6) * (k1 + 4 *k2 + k3) 
    return k_x_i

def runge_kutta(fun, x_start):
    time = 0
    x_i = x_start
    conc_plot = array('f', [x_start[0][0]])
    temp_plot = array('f', [x_start[1][0]])
    time_plot = array('f',[time])
    while time + h < end_time:
        
        x_i = kaef(time,h,x_i,fun)
        
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time += h
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


#Правило Рунге
def runge_rule(rr_fun, rr_x_start, r_h, eps):
    n = math.floor((end_time - start_time)/r_h)
    rr_h = r_h
    time = 0
    x_i = rr_x_start
    conc_plot = array('f', [rr_x_start[0][0]])
    temp_plot = array('f', [rr_x_start[1][0]])
    time_plot = array('f',[time])
    while time + rr_h < end_time:
        x_i_1 = kaef(time, rr_h, x_i, rr_fun)
        x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        while abs(x_i_1[0][0]- x_i_2[0][0])/31 >= eps:
            rr_h = rr_h / 2
            x_i_1 = kaef(time, rr_h, x_i, rr_fun)
            x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        x_i = x_i_1
        time += rr_h
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


print('x- лимфоциты\nу - раковые клетки \nГрафики зависимостей количества лимфоцитов от количества раковых клеток с учетом их связи BETA2')
##########################################


xxx = [x0,x04,x08]
for i in xxx:
    

    conc_pl,temp_pl, time_pl = runge_kutta(react_system, i)
    rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, i, 0.01, epsilon)
 


    plt.figure(figsize=(10,7))
    plt.subplot(3, 3, 1)
    plt.title("График зависимости (x, t) ")
    plt.grid()
    
    plt.plot(time_pl, conc_pl, color = "black")
    
    plt.subplot(3, 3, 2)
    plt.title("График зависимости (y, t) " )
    plt.grid()
    plt.plot(time_pl, temp_pl, color="blue")

   
    plt.subplot(3,3,3)
    plt.title("График решения (x, y) ")
    plt.grid()
    plt.plot(conc_pl, temp_pl, color="r")
    

    plt.show()
plt.plot(conc_pl, temp_pl, color="r")    
plt.show()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
# Out:
# x- лимфоциты
# у - раковые клетки
# Графики зависимостей количества лимфоцитов от количества раковых клеток с учетом их связи BETA2
# C:\Users\admin\AppData\Local\Temp\ipykernel_21036\1773936091.py:31: RuntimeWarning: invalid value encountered in power
#   yy2_3 = np.power(yy,2/3)

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from array import *
import random

h = 0.001
start_time = 0
end_time = 20
epsilon = 0.001
beta2 = 5

random_range = round( random.random()* (9.01 - 0.5) + 0.5 ,3 ) # случайное число из[0.5,9]
x0 = np.array([[1],[1]],dtype = float)
x01 = np.array([[1],[2]],dtype = float)
x02 = np.array([[1],[3]],dtype = float)
x03 = np.array([[1],[4]],dtype = float)
x04 = np.array([[1],[5]],dtype = float)
x05 = np.array([[1],[6]],dtype = float)
x06 = np.array([[1],[7]],dtype = float)
x07 = np.array([[1],[8]],dtype = float)
x08 = np.array([[1],[9]],dtype = float)
print ('y0 = ', random_range, ' - начальное количество раковых клеток.' )



def react_system(time, x):  
    xx = x[0][0]
    yy = x[1][0]
    yy2_3 = np.power(yy,2/3)

    return np.array([[-1 + yy2_3 * (1-xx/3)*(1+xx)*xx ], [((-beta2)*xx*yy2_3/(1+xx) ) + yy ] ])


#Рунге - Кутта
def kaef(k_time, k_h, k_x_i, k_fun):
    k1 = k_h * k_fun(k_time, k_x_i)
    k2 = k_h * k_fun(k_time + k_h/3, k_x_i + k1/3)
    k3 = k_h * k_fun(k_time + k_h/3, k_x_i + (k1+k2)/6)

    k_x_i = k_x_i + (1/6) * (k1 + 4 *k2 + k3) 
    return k_x_i

def runge_kutta(fun, x_start):
    time = 0
    x_i = x_start
    conc_plot = array('f', [x_start[0][0]])
    temp_plot = array('f', [x_start[1][0]])
    time_plot = array('f',[time])
    while time + h < end_time:
        
        x_i = kaef(time,h,x_i,fun)
        
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time += h
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


#Правило Рунге
def runge_rule(rr_fun, rr_x_start, r_h, eps):
    n = math.floor((end_time - start_time)/r_h)
    rr_h = r_h
    time = 0
    x_i = rr_x_start
    conc_plot = array('f', [rr_x_start[0][0]])
    temp_plot = array('f', [rr_x_start[1][0]])
    time_plot = array('f',[time])
    while time + rr_h < end_time:
        x_i_1 = kaef(time, rr_h, x_i, rr_fun)
        x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        while abs(x_i_1[0][0]- x_i_2[0][0])/31 >= eps:
            rr_h = rr_h / 2
            x_i_1 = kaef(time, rr_h, x_i, rr_fun)
            x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        x_i = x_i_1
        time += rr_h
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


print('x- лимфоциты\nу - раковые клетки \nГрафики зависимостей количества лимфоцитов от количества раковых клеток с учетом их связи BETA2')
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x07)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x0, 0.01, epsilon)


plt.figure(figsize=(10,7))
plt.subplot(3, 3, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(3, 3, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(3,3,3)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x01)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x01, 0.01, epsilon)

plt.figure(figsize=(10,7))
plt.subplot(3, 3, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(3, 3, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(3,3,3)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x02)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x02, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x03)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x03, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x04)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x04, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x05)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x05, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x06)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x06, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x07)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x07, 0.01, epsilon)

# conc_pl,temp_pl, time_pl = runge_kutta(react_system, x08)
# rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x08, 0.01, epsilon)


plt.figure(figsize=(10,7))
plt.subplot(3, 3, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(3, 3, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(3,3,3)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
# Out:
# y0 =  6.862  - начальное количество раковых клеток.
# x- лимфоциты
# у - раковые клетки
# Графики зависимостей количества лимфоцитов от количества раковых клеток с учетом их связи BETA2
# C:\Users\admin\AppData\Local\Temp\ipykernel_3832\2646447201.py:30: RuntimeWarning: invalid value encountered in power
#   yy2_3 = np.power(yy,2/3)

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from array import *

h = 0.001
start_time = 0
end_time = 20
epsilon = 0.001
beta2 = 5

random_range = round( random.random()* (9.01 - 0.5) + 0.5 ,3 ) # случайное число из[0.5,9]
x0 = np.array([[1],[1]],dtype = float)
x01 = np.array([[1],[2]],dtype = float)
x02 = np.array([[1],[3]],dtype = float)
x03 = np.array([[1],[4]],dtype = float)
x04 = np.array([[1],[5]],dtype = float)
x05 = np.array([[1],[6]],dtype = float)
x06 = np.array([[1],[7]],dtype = float)
x07 = np.array([[1],[8]],dtype = float)
x08 = np.array([[1],[9]],dtype = float)
print ('y0 = ', random_range )



def react_system(time, x):  
    xx = x[0][0]
    yy = x[1][0]
    yy2_3 = pow(yy,2/3)
    #print('y^2/3 = ', yy2_3)
    return np.array([[-1 + yy2_3 * (1-xx/3)*(1+xx)*xx ], [((-beta2)*xx*yy2_3/(1+xx) ) + yy ] ])


#Рунге - Кутта
def kaef(k_time, k_h, k_x_i, k_fun):
    k1 = k_h * k_fun(k_time, k_x_i)
    k2 = k_h * k_fun(k_time + k_h/3, k_x_i + k1/3)
    k3 = k_h * k_fun(k_time + k_h/3, k_x_i + (k1+k2)/6)
#     k4 = k_h * k_fun(k_time + k_h/2, k_x_i + k1/8 +3*k3/8)
#     k5 = k_h * k_fun(k_time + k_h, k_x_i + k1/2 - 3*k3/2 + 2*k4)
    k_x_i = k_x_i + (1/6) * (k1 + 4 *k2 + k3) 
    return k_x_i

def runge_kutta(fun, x_start):
    time = 0
    x_i = x_start
    conc_plot = array('f', [x_start[0][0]])
    temp_plot = array('f', [x_start[1][0]])
    time_plot = array('f',[time])
    while time + h < end_time:
        
        x_i = kaef(time,h,x_i,fun)
        
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time += h
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


#Правило Рунге
def runge_rule(rr_fun, rr_x_start, r_h, eps):
    n = math.floor((end_time - start_time)/r_h)
    rr_h = r_h
    time = 0
    x_i = rr_x_start
    conc_plot = array('f', [rr_x_start[0][0]])
    temp_plot = array('f', [rr_x_start[1][0]])
    time_plot = array('f',[time])
    while time + rr_h < end_time:
        x_i_1 = kaef(time, rr_h, x_i, rr_fun)
        x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        while abs(x_i_1[0][0]- x_i_2[0][0])/31 >= eps:
            rr_h = rr_h / 2
            x_i_1 = kaef(time, rr_h, x_i, rr_fun)
            x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        x_i = x_i_1
        time += rr_h
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x0)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x0, 0.01, epsilon)

plt.figure(figsize=(10,7))
plt.subplot(2, 2, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(2, 2, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(2,2,4)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x01)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x01, 0.01, epsilon)

plt.figure(figsize=(10,7))
plt.subplot(2, 2, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(2, 2, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(2,2,4)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()
##########################################

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x02)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x02, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x03)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x03, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x04)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x04, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x05)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x05, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x06)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x06, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x07)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x07, 0.01, epsilon)

conc_pl,temp_pl, time_pl = runge_kutta(react_system, x08)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x08, 0.01, epsilon)


plt.figure(figsize=(10,7))
plt.subplot(2, 2, 1)
plt.title("График решения (x, y) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(2, 2, 2)
plt.title("График зависимости (y, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(2,2,4)
plt.title("График зависимости (x, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()

# %%
# Out:
# 1.5874010519681994

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SYCHEV~1\AppData\Local\Temp/ipykernel_16712/629000238.py in <module>
#       1 import random
# ----> 2 random.randfloat(0, 10, 0.1)
#
# AttributeError: module 'random' has no attribute 'randfloat'

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from array import *
import random

lamb = 0.45
beta = 45
c0 = 125
t0 = 0.23
h = 0.001
end_time = 15
start_time = 0
epsilon = 0.001



x0 = np.array([[120],[0.23]],dtype = float)

#уравнения
def react_system(time, x):
    return np.array([[-x[0][0] * np.exp(-1/x[1][0])+ lamb*(c0 - x[0][0])], [x[0][0] * 
                                                                            np.exp(-1/x[1][0])+beta  * (t0 - x[1][0])]])


#Рунге - Кутта
def kaef(k_time, k_h, k_x_i, k_fun):
    k1 = k_h * k_fun(k_time, k_x_i)
    k2 = k_h * k_fun(k_time + k_h/3, k_x_i + k1/3)
    k3 = k_h * k_fun(k_time + k_h/3, k_x_i + (k1+k2)/6)
    k4 = k_h * k_fun(k_time + k_h/2, k_x_i + k1/8 +3*k3/8)
    k5 = k_h * k_fun(k_time + k_h, k_x_i + k1/2 - 3*k3/2 + 2*k4)
    k_x_i = k_x_i + (1/6) * (k1 + 4 *k4 + k5) 
    return k_x_i

def runge_kutta(fun, x_start):
    time = 0
    x_i = x_start
    conc_plot = array('f', [x_start[0][0]])
    temp_plot = array('f', [x_start[1][0]])
    time_plot = array('f',[time])
    while time + h < end_time:
        
        x_i = kaef(time,h,x_i,fun)
        
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time += h
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


#Правило Рунге
def runge_rule(rr_fun, rr_x_start, r_h, eps):
    n = math.floor((end_time - start_time)/r_h)
    rr_h = r_h
    time = 0
    x_i = rr_x_start
    conc_plot = array('f', [rr_x_start[0][0]])
    temp_plot = array('f', [rr_x_start[1][0]])
    time_plot = array('f',[time])
    while time + rr_h < end_time:
        x_i_1 = kaef(time, rr_h, x_i, rr_fun)
        x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        while abs(x_i_1[0][0]- x_i_2[0][0])/31 >= eps:
            rr_h = rr_h / 2
            x_i_1 = kaef(time, rr_h, x_i, rr_fun)
            x_i_2 = kaef(time, rr_h/2, x_i, rr_fun)
        x_i = x_i_1
        time += rr_h
        conc_plot.append(x_i[0][0])
        temp_plot.append(x_i[1][0])
        time_plot.append(time)
    return conc_plot, temp_plot, time_plot


conc_pl,temp_pl, time_pl = runge_kutta(react_system, x0)
rr_conc_pl, rr_temp_pl, rr_time_pl = runge_rule(react_system, x0, 0.01, epsilon)


plt.figure(figsize=(10,7))
plt.subplot(2, 2, 1)
plt.title("График решения (с, Т) ")
plt.grid()
plt.plot(conc_pl, temp_pl, color="r")

plt.subplot(2, 2, 2)
plt.title("График зависимости (Т, t) " )
plt.grid()
plt.plot(time_pl, temp_pl, color="blue")
plt.subplot(2,2,4)
plt.title("График зависимости (с, t) ")
plt.grid()
plt.plot(rr_conc_pl, rr_temp_pl, color = "black")
plt.show()

# %%
# Out:
# 2.122
